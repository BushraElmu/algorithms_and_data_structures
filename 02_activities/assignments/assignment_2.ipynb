# %% [markdown]
# # Practice Interview
#
# ## Objective
#
# _*The partner assignment aims to provide participants with the opportunity to practice coding in an interview context. You will analyze your partner's Assignment 1. Moreover, code reviews are common practice in a software development team. This assignment should give you a taste of the code review process.*_
#
# ## Group Size
#
# Each group should have 2 people. You will be assigned a partner
#
# ## Parts:
# - Part 1: Complete 1 of 3 questions
# - Part 2: Review your partner's Assignment 1 submission
# - Part 3: Perform code review of your partner's assignment 1 by answering the questions below
# - Part 3: Reflect on Assignment 1 and Assignment 2
#
# ## Part 1:
#
# _*You will be assigned one of three problems based of your first name. Enter your first name, in all lower case, execute the code below, and that will tell you your assigned problem. Include the output as part of your submission (do not clear the output). The problems are based-off problems from Leetcode.*_

# %%
import hashlib

def hash_to_range(input_string: str) -> int:
     hash_object = hashlib.sha256(input_string.encode())
     hash_int = int(hash_object.hexdigest(), 16)
     return (hash_int % 3) + 1
input_string = "bushra"
result = hash_to_range(input_string)
print(result)
# Out:
# 1

# %% [markdown]
# <details>
#   <summary>Question 1</summary>
#
#   # Question One: Check Duplicates in Tree
#
#   Given the `root` of a binary tree, check whether it is contains a duplicate value. If a duplicate exists, return the duplicate value. If there are multiple duplicates, return the one with the closest distance to the root. If no duplicate exists, return -1.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: 2
#
#   ### Example 2
#
#   ![](./images/q1_ex2.png)
#
#   Input: `root = [1, 10, 2, 3, 10, 12, 12]`
#
#   Output: 10
#
#   ### Example 3
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 8, 7]`
#
#   Output: -1
#
# </details>
#
# #### Starter Code for Question 1

# %%
# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, val = 0, left = None, right = None):
        self.val = val
        self.left = left
        self.right = right

from collections import deque

def is_duplicate(root: TreeNode) -> int:
    if root is None:
        return -1

    seen = set()
    queue = deque([root])

    while queue:
        current = queue.popleft()

        if current.val in seen:
            return current.val

        seen.add(current.val)

        if current.left is not None:
            queue.append(current.left)

        if current.right is not None:
            queue.append(current.right)

    return -1

# %% [markdown]
# <details>
#   <summary>Question 2</summary>
#
#   # Question Two: Path to Leaves
#
#   Given the `root` of a binary tree, return all root to leaf paths in any order.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: [[1, 2, 3], [1, 2, 5], [1, 2, 6], [1, 2, 7]]
#
#   ### Example 2
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 7, 8]`
#
#   Output: [[10, 7], [10, 9, 8]]
#
# </details>
#
# #### Starter Code for Question 2

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val = 0, left = None, right = None):
#         self.val = val
#         self.left = left
#         self.right = right
def bt_path(root: TreeNode) -> List[List[int]]:
  # TODO

# %% [markdown]
# <details>
#   <summary>Question 3</summary>
#
#   # Question Three: Missing Number in Range
#
#   You are given a list containing `n` integers in the range `[1, n]`. Return a list of numbers that are missing from the range `[1, n]` of the array. If there is no missing number, return -1. Note, all the integers in the list may not be unique.
#
#   ## Examples
#
#   ### Example 1
#
#   Input: `lst = [1, 1, 3]`
#
#   Output: [2]
#
#   ### Example 2
#
#   Input: `lst = [5,3,2,4,1]`
#
#   Output: [-1]
#
#   ### Example 3
#
#   Input: `lst = [6, 8, 2, 3, 5, 7, 1, 1, 2,10]`
#
#   Output: [4, 9]
#
# </details>
#
# #### Starter Code for Question 3

# %%
def missing_num(nums: List) -> int:
  # TODO

# %% [markdown]
# ## Part 2:
#
# You and your partner must share each other's Assignment 1 submission.

# %% [markdown]
# ## Part 3:
#
# Create a Jupyter Notebook, create 6 of the following headings, and complete the following for your partner's assignment 1:
#
# -   Paraphrase the problem in your own words.

# %% [markdown]
# ### Your answer here
#
# The problem asks us to take a list of integers and move every 0 to the end of the list. The order of the non-zero numbers should stay the same. The function should return the updated list.

# %% [markdown]
# -   Create 1 new example that demonstrates you understand the problem. Trace/walkthrough 1 example that your partner made and explain it.

# %%
### Your answer here

# New Example

# Input: 
nums1 = [0, 2, 0, 0, 3]
# Output: [2, 3, 0, 0, 0]

# This works because the non-zero values are 2 and 3, and they stay in the same relative order. The three zeros are moved to the end.

# %%
# Partner Exaple

# Input: 
nums2 = [4, 0, 5, 0, 0, 6]
# Output: [4, 5, 6, 0, 0, 0]

# The function checks each number in the list. It adds 4, 5, and 6 to a new list because they are not zero. It counts the three zeros separately. 
# After the first loop, the new list is [4, 5, 6] and the zero count is 3. The second loop appends three zeros to the end, giving [4, 5, 6, 0, 0, 0].

# %% [markdown]
# -   Copy the solution your partner wrote.

# %%
# Partner Code:
# Question Three: Move All Zeros to End

# Given a list of integers, move all zeros to the end while maintaining the relative order of the non-zero elements. 

from typing import List

def move_zeros_to_end(nums: List[int]) -> List[int]:
    # TODO
    countzero = 0
    answer = []
    
    
    for num in nums:
        if num != 0:
            answer.append(num)
        else:
            countzero += 1
            
    for i in range(countzero):
        answer.append(0)

pass

# %%
print(move_zeros_to_end(nums1))
print(move_zeros_to_end(nums2))
# Out:
# None
# None

# %% [markdown]
# -   Explain why their solution works in your own words.

# %% [markdown]
# ### Your answer here
#
# Their solution works by separating the problem into two steps. First, they loop through the input list and copy every non-zero number into a new list called answer also keeping the original order. The function also counts how many zeros were found with the variable countzero and later it appends that many zeros to the end of answer. That gives the correct final list with all non-zero values first in preserved order, and all zeros at the end.

# %% [markdown]
# -   Explain the problem’s time and space complexity in your own words.

# %% [markdown]
# ### Your answer here
#
# The time complexity is O(n), where n is the length of the input list. The function loops through the original list once to append non-zero values to the answer list and count how many zeros there are. It then loops through the number of zeros to append them to the end.
#
# The space complexity is O(n) because the solution creates a new list called answer. In the worst case, this new list stores the same number of elements as the original input list.

# %% [markdown]
# -   Critique your partner's solution, including explanation, and if there is anything that should be adjusted.

# %% [markdown]
# ### Your answer here
#
# The solution is correct and easy to follow. It preserves the order of the non-zero elements in a straightforward and simple manner and moves the correct number of zeros to the end. The explanation also correctly identifies that the function uses one pass to collect non-zero values and count zeros, then another pass to append the zeros.
#
# One improvement would be to mention that this solution is not in-place. It creates a new list, so it uses O(n) extra space. A more space-efficient alternative would be a two-pointer approach that modifies the original list and uses O(1) extra space. Their alternative solution actually suggests this.
#
# Another improvement would be to make sure the function includes a `return` statement. In a notebook, it is common to print or display intermediate results, but in real code functions should return the final result so it can be reused and tested.

# %% [markdown]
# ## Part 4:
#
# Please write a 200 word reflection documenting your process from assignment 1, and your presentation and review experience with your partner at the bottom of the Jupyter Notebook under a new heading "Reflection." Again, export this Notebook as pdf.

# %% [markdown]
# ### Reflection

# %% [markdown]
# ### Your answer here
#
# For my Assignment 1, I was tasked with finding the first duplicate in a list. My approach was to scan through the list from left to right and keep track of values that had already appeared. I used a set because the problem involved duplicates, and sets naturally relate to uniqueness. This made the solution easier to write because I could check whether each value had already been seen, return it if it had, and return `-1` if no duplicate was found.
#
# Upon reflection, a list rather than a set could also have kept track of previously seen values and produce the same result. Especially since the function never utilized the membership / deduplication feature of sets. However, I think the mindset of selecting a set reflected the intention of working with duplicates and of tracking the values that appear.
#
# I also noticed that my interpretation of “first duplicate” may be different from someone else’s. I interpreted it as the number whose second appearance / "duplicate" is encountered first while scanning the list. However, it could also mean the duplicated number whose first appearance comes earliest in the original list (the first number in a list of only duplicates). Those interpretations require different solutions, so this reminded me that reading the problem statement carefully matters.
#
# For my partner’s question, the task was to move zeros to the end of the list while maintaining the order of the non-zero values. Their solution used a new list for non-zero numbers and a counter for zeros to append afterward. Their solution was simple, clear, and correct. Reviewing their work made me think about readability as part of a good solution. Their function was easy to follow, and the time and space complexity were straightforward to explain.
#
# Overall, I had some familiarity with data structures and algorithms before this assignment, but reviewing both solutions helped me practice explaining my choices more clearly. It also made me more aware of data structure choice, time complexity, space complexity, and the importance of writing reusable functions.

# %% [markdown]
# ## Evaluation Criteria
#
# We are looking for the similar points as Assignment 1
#
# -   Problem is accurately stated
#
# -   New example is correct and easily understandable
#
# -   Correctness, time, and space complexity of the coding solution
#
# -   Clarity in explaining why the solution works, its time and space complexity
#
# -   Quality of critique of your partner's assignment, if necessary

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-2`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_2.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/algorithms_and_data_structures/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [√ ] Created a branch with the correct naming convention.
# - [√] Ensured that the repository is public.
# - [√ ] Reviewed the PR description guidelines and adhered to them.
# - [√ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-6-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
